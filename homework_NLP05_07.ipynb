# %% [markdown]
# ### 作业07
# #### 利用条件随机场实现NER
# - 用kaggle的ner数据集
# - 提交完整代码
# - 汇报模型评测结果

# %% [markdown]
# #### 1. 读入Kaggle的数据

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report
# Out:
# /Users/libo/opt/anaconda3/envs/HanLP/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
df = pd.read_csv('ner_dataset.csv', encoding = "ISO-8859-1")
df = df[:100000]

# %%
df.head()
# Out:
#     Sentence #           Word  POS Tag
# 0  Sentence: 1      Thousands  NNS   O
# 1          NaN             of   IN   O
# 2          NaN  demonstrators  NNS   O
# 3          NaN           have  VBP   O
# 4          NaN        marched  VBN   O

# %% [markdown]
# #### 从上面可以看到数据的第一列表明是句子的标号,同一个句子的词语只有第一个句首词语标明句子号，其余的词语则为空，第二列是关于句子中的不同单词，第三列是POS代表词性(Part of Speech Tag), 第三列是TAG表示命名实体标注
# ([
#  ORGANIZATION - Georgia-Pacific Corp., WHO
# PERSON - Eddy Bonte, President Obama
# LOCATION - Murray River, Mount Everest
# DATE - June, 2008-06-29
# TIME - two fifty a m, 1:30 p.m.
# MONEY - 175 million Canadian Dollars, GBP 10.40
# PERCENT - twenty pct, 18.75 %
# FACILITY - Washington Monument, Stonehenge
# GPE - South East Asia, Midlothian
# ])

# %% [markdown]
# #### 2. 对数据进行预处理

# %%
df = df.fillna(method='ffill')
df['Sentence #'].nunique(), df.Word.nunique(), df.Tag.nunique()
# Out:
# (4544, 10922, 17)

# %% [markdown]
# - 对数据进行去重

# %%
df.head()
# Out:
#     Sentence #           Word  POS Tag
# 0  Sentence: 1      Thousands  NNS   O
# 1  Sentence: 1             of   IN   O
# 2  Sentence: 1  demonstrators  NNS   O
# 3  Sentence: 1           have  VBP   O
# 4  Sentence: 1        marched  VBN   O

# %% [markdown]
# - 对数据按照命名实体进行聚类，计算相同词性的数量

# %%
df.groupby('Tag').size().reset_index(name='counts')
# Out:
#       Tag  counts
# 0   B-art      75
# 1   B-eve      53
# 2   B-geo    3303
# 3   B-gpe    1740
# 4   B-nat      30
# 5   B-org    1876
# 6   B-per    1668
# 7   B-tim    1823
# 8   I-art      43
# 9   I-eve      47
# 10  I-geo     690
# 11  I-gpe      51
# 12  I-nat      11
# 13  I-org    1470
# 14  I-per    1846
# 15  I-tim     549
# 16      O   84725

# %% [markdown]
# #### 3. 建立CRF模型

# %%
# !pip install sklearn-crfsuite
# Out:
# Collecting sklearn-crfsuite
#   Downloading sklearn_crfsuite-0.3.6-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: tqdm>=2.0 in /Users/libo/opt/anaconda3/envs/HanLP/lib/python3.7/site-packages (from sklearn-crfsuite) (4.51.0)
# Collecting tabulate
#   Downloading tabulate-0.8.7-py3-none-any.whl (24 kB)
# Requirement already satisfied: six in /Users/libo/.local/lib/python3.7/site-packages (from sklearn-crfsuite) (1.14.0)
# Collecting python-crfsuite>=0.8.3
#   Downloading python_crfsuite-0.9.7-cp37-cp37m-macosx_10_13_x86_64.whl (186 kB)
#      |████████████████████████████████| 186 kB 956 kB/s eta 0:00:01
# Installing collected packages: tabulate, python-crfsuite, sklearn-crfsuite
# Successfully installed python-crfsuite-0.9.7 sklearn-crfsuite-0.3.6 tabulate-0.8.7

# %%
import sklearn_crfsuite
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics
from collections import Counter

# %%
class SentenceGetter(object):
    def __init__(self, data):
        self.n_sent = 1
        self.data = data
        self.empty = False
        agg_func = lambda s:[(w, p, t) for w, p, t in zip(s['Word'].values.tolist(), s['POS'].values.tolist(), s['Tag'].values.tolist())]
        self.grouped = self.data.groupby('Sentence #').apply(agg_func)
        self.sentences = [s for s in self.grouped]
    
    def get_next(self):
        try:
            s = self.grouped['Sentence: {}'.format(self.n_sent)]
            self.n_sent += 1
            return s
        except:
            return None
    
getter = SentenceGetter(df)
sentences = getter.sentences

# %%
sentences
# Out:
# [[('Thousands', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('demonstrators', 'NNS', 'O'),
#   ('have', 'VBP', 'O'),
#   ('marched', 'VBN', 'O'),
#   ('through', 'IN', 'O'),
#   ('London', 'NNP', 'B-geo'),
#   ('to', 'TO', 'O'),
#   ('protest', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('war', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('Iraq', 'NNP', 'B-geo'),
#   ('and', 'CC', 'O'),
#   ('demand', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('withdrawal', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('British', 'JJ', 'B-gpe'),
#   ('troops', 'NNS', 'O'),
#   ('from', 'IN', 'O'),
#   ('that', 'DT', 'O'),
#   ('country', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Iranian', 'JJ', 'B-gpe'),
#   ('officials', 'NNS', 'O'),
#   ('say', 'VBP', 'O'),
#   ('they', 'PRP', 'O'),
#   ('expect', 'VBP', 'O'),
#   ('to', 'TO', 'O'),
#   ('get', 'VB', 'O'),
#   ('access', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('sealed', 'JJ', 'O'),
#   ('sensitive', 'JJ', 'O'),
#   ('parts', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('plant', 'NN', 'O'),
#   ('Wednesday', 'NNP', 'B-tim'),
#   (',', ',', 'O'),
#   ('after', 'IN', 'O'),
#   ('an', 'DT', 'O'),
#   ('IAEA', 'NNP', 'B-org'),
#   ('surveillance', 'NN', 'O'),
#   ('system', 'NN', 'O'),
#   ('begins', 'VBZ', 'O'),
#   ('functioning', 'VBG', 'O'),
#   ('.', '.', 'O')],
#  [('Helicopter', 'NN', 'O'),
#   ('gunships', 'NNS', 'O'),
#   ('Saturday', 'NNP', 'B-tim'),
#   ('pounded', 'VBD', 'O'),
#   ('militant', 'JJ', 'O'),
#   ('hideouts', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Orakzai', 'NNP', 'B-geo'),
#   ('tribal', 'JJ', 'O'),
#   ('region', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('where', 'WRB', 'O'),
#   ('many', 'JJ', 'O'),
#   ('Taliban', 'NNP', 'B-org'),
#   ('militants', 'NNS', 'O'),
#   ('are', 'VBP', 'O'),
#   ('believed', 'VBN', 'O'),
#   ('to', 'TO', 'O'),
#   ('have', 'VB', 'O'),
#   ('fled', 'VBN', 'O'),
#   ('to', 'TO', 'O'),
#   ('avoid', 'VB', 'O'),
#   ('an', 'DT', 'O'),
#   ('earlier', 'JJR', 'O'),
#   ('military', 'JJ', 'O'),
#   ('offensive', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('nearby', 'JJ', 'O'),
#   ('South', 'NNP', 'B-geo'),
#   ('Waziristan', 'NNP', 'I-geo'),
#   ('.', '.', 'O')],
#  [('They', 'PRP', 'O'),
#   ('left', 'VBD', 'O'),
#   ('after', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('tense', 'NN', 'O'),
#   ('hour-long', 'JJ', 'O'),
#   ('standoff', 'NN', 'O'),
#   ('with', 'IN', 'O'),
#   ('riot', 'NN', 'O'),
#   ('police', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('global', 'JJ', 'O'),
#   ('financial', 'JJ', 'O'),
#   ('crisis', 'NN', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('left', 'VBN', 'O'),
#   ('Iceland', 'NNP', 'B-org'),
#   ("'s", 'POS', 'O'),
#   ('economy', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('shambles', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('Three', 'CD', 'O'),
#   ('major', 'JJ', 'O'),
#   ('banks', 'NNS', 'O'),
#   ('have', 'VBP', 'O'),
#   ('collapsed', 'VBN', 'O'),
#   (',', ',', 'O'),
#   ('unemployment', 'NN', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('soared', 'VBN', 'O'),
#   (',', ',', 'O'),
#   ('and', 'CC', 'O'),
#   ('the', 'DT', 'O'),
#   ('value', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('krona', 'NN', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('plunged', 'VBN', 'O'),
#   ('.', '.', 'O')],
#  [('Prime', 'JJ', 'O'),
#   ('Minister', 'NN', 'O'),
#   ('Geir', 'NNP', 'B-per'),
#   ('Haarde', 'NNP', 'I-per'),
#   ('has', 'VBZ', 'O'),
#   ('refused', 'VBN', 'O'),
#   ('to', 'TO', 'O'),
#   ('resign', 'VB', 'O'),
#   ('or', 'CC', 'O'),
#   ('call', 'VB', 'O'),
#   ('for', 'IN', 'O'),
#   ('early', 'JJ', 'O'),
#   ('elections', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('He', 'PRP', 'O'),
#   ('blames', 'VBZ', 'O'),
#   ('Iceland', 'NNP', 'B-org'),
#   ("'s", 'POS', 'O'),
#   ('economic', 'JJ', 'O'),
#   ('calamity', 'NN', 'O'),
#   ('on', 'IN', 'O'),
#   ('commercial', 'JJ', 'O'),
#   ('bankers', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('government', 'NN', 'O'),
#   ('was', 'VBD', 'O'),
#   ('forced', 'VBN', 'O'),
#   ('to', 'TO', 'O'),
#   ('ask', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('International', 'NNP', 'B-org'),
#   ('Monetary', 'NNP', 'I-org'),
#   ('Fund', 'NNP', 'I-org'),
#   ('and', 'CC', 'O'),
#   ('several', 'JJ', 'O'),
#   ('countries', 'NNS', 'O'),
#   ('for', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('multi-billion-dollar', 'JJ', 'O'),
#   ('loan', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Global', 'JJ', 'O'),
#   ('health', 'NN', 'O'),
#   ('experts', 'NNS', 'O'),
#   ('said', 'VBD', 'O'),
#   ('cancer', 'NN', 'O'),
#   ('will', 'MD', 'O'),
#   ('become', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('leading', 'VBG', 'O'),
#   ('cause', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('death', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('world', 'NN', 'O'),
#   ('by', 'IN', 'O'),
#   ('2010', 'CD', 'B-tim'),
#   (',', ',', 'O'),
#   ('overtaking', 'VBG', 'O'),
#   ('heart', 'NN', 'O'),
#   ('disease', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('A', 'DT', 'O'),
#   ('World', 'NNP', 'O'),
#   ('Health', 'NNP', 'O'),
#   ('Organization', 'NNP', 'O'),
#   ('report', 'NN', 'O'),
#   ('issued', 'VBN', 'O'),
#   ('Tuesday', 'NNP', 'B-tim'),
#   ('said', 'VBD', 'O'),
#   ('one', 'CD', 'O'),
#   ('factor', 'NN', 'O'),
#   ('behind', 'IN', 'O'),
#   ('cancer', 'NN', 'O'),
#   ("'s", 'POS', 'O'),
#   ('growing', 'VBG', 'O'),
#   ('deadliness', 'NN', 'O'),
#   ('is', 'VBZ', 'O'),
#   ('rising', 'VBG', 'O'),
#   ('cigarette', 'NN', 'O'),
#   ('smoking', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('developing', 'VBG', 'O'),
#   ('countries', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('40', 'CD', 'O'),
#   ('percent', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('world', 'NN', 'O'),
#   ("'s", 'POS', 'O'),
#   ('smokers', 'NNS', 'O'),
#   ('are', 'VBP', 'O'),
#   ('thought', 'VBN', 'O'),
#   ('to', 'TO', 'O'),
#   ('live', 'VB', 'O'),
#   ('in', 'IN', 'O'),
#   ('China', 'NNP', 'B-geo'),
#   ('and', 'CC', 'O'),
#   ('India', 'NNP', 'B-geo'),
#   ('alone', 'RB', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('WHO', 'NNP', 'B-org'),
#   ('report', 'NN', 'O'),
#   ('said', 'VBD', 'O'),
#   ('an', 'DT', 'O'),
#   ('estimated', 'VBN', 'O'),
#   ('12', 'CD', 'O'),
#   ('million', 'CD', 'O'),
#   ('people', 'NNS', 'O'),
#   ('will', 'MD', 'O'),
#   ('be', 'VB', 'O'),
#   ('diagnosed', 'VBN', 'O'),
#   ('with', 'IN', 'O'),
#   ('some', 'DT', 'O'),
#   ('form', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('cancer', 'NN', 'O'),
#   ('this', 'DT', 'O'),
#   ('year', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('Pakistani', 'JJ', 'B-gpe'),
#   ('military', 'NN', 'O'),
#   ('launched', 'VBD', 'O'),
#   ('its', 'PRP$', 'O'),
#   ('offensive', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('Orakzai', 'NNP', 'B-geo'),
#   ('to', 'TO', 'O'),
#   ('hunt', 'VB', 'O'),
#   ('Taliban', 'NNP', 'B-org'),
#   ('insurgents', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('It', 'PRP', 'O'),
#   ('predicts', 'VBZ', 'O'),
#   ('that', 'IN', 'O'),
#   ('7.6', 'CD', 'O'),
#   ('million', 'CD', 'O'),
#   ('of', 'IN', 'O'),
#   ('them', 'PRP', 'O'),
#   ('will', 'MD', 'O'),
#   ('die', 'VB', 'O'),
#   ('.', '.', 'O')],
#  [('Health', 'NN', 'O'),
#   ('experts', 'NNS', 'O'),
#   ('predicted', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('number', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('people', 'NNS', 'O'),
#   ('who', 'WP', 'O'),
#   ('die', 'VBP', 'O'),
#   ('from', 'IN', 'O'),
#   ('cancer', 'NN', 'O'),
#   ('will', 'MD', 'O'),
#   ('soon', 'RB', 'O'),
#   ('be', 'VB', 'O'),
#   ('greater', 'JJR', 'O'),
#   ('than', 'IN', 'O'),
#   ('deaths', 'NNS', 'O'),
#   ('from', 'IN', 'O'),
#   ('AIDS', 'NNP', 'B-nat'),
#   (',', ',', 'O'),
#   ('tuberculosis', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('malaria', 'NN', 'O'),
#   ('combined', 'VBN', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('WHO', 'NNP', 'B-org'),
#   ('said', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('number', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('new', 'JJ', 'O'),
#   ('cancer', 'NN', 'O'),
#   ('patients', 'NNS', 'O'),
#   ('may', 'MD', 'O'),
#   ('rise', 'VB', 'O'),
#   ('to', 'TO', 'O'),
#   ('27', 'CD', 'O'),
#   ('million', 'CD', 'O'),
#   ('a', 'DT', 'O'),
#   ('year', 'NN', 'O'),
#   ('by', 'IN', 'O'),
#   ('2030', 'CD', 'B-tim'),
#   (',', ',', 'O'),
#   ('with', 'IN', 'O'),
#   ('17', 'CD', 'O'),
#   ('million', 'CD', 'O'),
#   ('people', 'NNS', 'O'),
#   ('dying', 'VBG', 'O'),
#   ('from', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('disease', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('A', 'DT', 'O'),
#   ('civil', 'JJ', 'O'),
#   ('liberties', 'NNS', 'O'),
#   ('group', 'NN', 'O'),
#   ('says', 'VBZ', 'O'),
#   ('it', 'PRP', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('obtained', 'VBN', 'O'),
#   ('documents', 'NNS', 'O'),
#   ('that', 'WDT', 'O'),
#   ('allegedly', 'RB', 'O'),
#   ('show', 'VBP', 'O'),
#   ('U.S.', 'NNP', 'B-org'),
#   ('military', 'JJ', 'O'),
#   ('forces', 'NNS', 'O'),
#   ('tried', 'VBD', 'O'),
#   ('to', 'TO', 'O'),
#   ('suppress', 'VB', 'O'),
#   ('reports', 'NNS', 'O'),
#   ('about', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('abuse', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('Iraqi', 'JJ', 'B-org'),
#   ('prisoners', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('documents', 'NNS', 'O'),
#   ('-', 'IN', 'O'),
#   ('released', 'VBN', 'O'),
#   ('by', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('American', 'NNP', 'B-org'),
#   ('Civil', 'NNP', 'I-org'),
#   ('Liberties', 'NNPS', 'I-org'),
#   ('Union', 'NNP', 'I-org'),
#   ('on', 'IN', 'O'),
#   ('Tuesday', 'NNP', 'B-tim'),
#   ('-', ':', 'I-tim'),
#   ('say', 'VBP', 'O'),
#   ('staff', 'NN', 'O'),
#   ('members', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Pentagon', 'NNP', 'B-org'),
#   ("'s", 'POS', 'I-org'),
#   ('Defense', 'NNP', 'I-org'),
#   ('Intelligence', 'NNP', 'I-org'),
#   ('Agency', 'NNP', 'I-org'),
#   ('(', 'LRB', 'O'),
#   ('DIA', 'NNP', 'B-org'),
#   (')', 'RRB', 'O'),
#   ('witnessed', 'VBD', 'O'),
#   ('several', 'JJ', 'O'),
#   ('incidents', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('abuse', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('including', 'VBG', 'O'),
#   ('prisoners', 'NNS', 'O'),
#   ('being', 'VBG', 'O'),
#   ('assaulted', 'VBN', 'O'),
#   (',', ',', 'O'),
#   ('deprived', 'VBN', 'O'),
#   ('of', 'IN', 'O'),
#   ('sleep', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('humiliated', 'VBN', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('documents', 'NNS', 'O'),
#   ('also', 'RB', 'O'),
#   ('included', 'VBD', 'O'),
#   ('complaints', 'NNS', 'O'),
#   ('that', 'IN', 'O'),
#   ('DIA', 'NNP', 'B-org'),
#   ('personnel', 'NNS', 'O'),
#   ('had', 'VBD', 'O'),
#   ('their', 'PRP$', 'O'),
#   ('e-mails', 'NNS', 'O'),
#   ('monitored', 'VBN', 'O'),
#   ('by', 'IN', 'O'),
#   ('special', 'JJ', 'O'),
#   ('forces', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('and', 'CC', 'O'),
#   ('were', 'VBD', 'O'),
#   ('ordered', 'VBN', 'O'),
#   ('"', '``', 'O'),
#   ('not', 'RB', 'O'),
#   ('to', 'TO', 'O'),
#   ('talk', 'VB', 'O'),
#   ('to', 'TO', 'O'),
#   ('anyone', 'DT', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('U.S.', 'NNP', 'B-geo'),
#   ('"', '``', 'I-geo'),
#   ('about', 'IN', 'O'),
#   ('what', 'WP', 'O'),
#   ('they', 'PRP', 'O'),
#   ('witnessed', 'VBD', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('ACLU', 'NNP', 'B-org'),
#   ('obtained', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('documents', 'NNS', 'O'),
#   ('after', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('federal', 'JJ', 'O'),
#   ('court', 'NN', 'O'),
#   ('ordered', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('Pentagon', 'NNP', 'B-org'),
#   ('to', 'TO', 'O'),
#   ('comply', 'VB', 'O'),
#   ('with', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('year-old', 'JJ', 'O'),
#   ('request', 'NN', 'O'),
#   ('under', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('U.S.', 'NNP', 'B-org'),
#   ('Freedom', 'NNP', 'I-org'),
#   ('of', 'IN', 'I-org'),
#   ('Information', 'NNP', 'I-org'),
#   ('Act', 'NNP', 'I-org'),
#   ('.', '.', 'O')],
#  [('Georgian', 'JJ', 'B-gpe'),
#   ('Prime', 'NNP', 'B-per'),
#   ('Minister', 'NNP', 'I-per'),
#   ('Zurab', 'NNP', 'I-per'),
#   ('Zhvania', 'NNP', 'I-per'),
#   ('says', 'VBZ', 'O'),
#   ('he', 'PRP', 'O'),
#   ('supports', 'VBZ', 'O'),
#   ('democracy', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('Ukraine', 'NNP', 'B-geo'),
#   ('and', 'CC', 'O'),
#   ('hopes', 'VBZ', 'O'),
#   ('the', 'DT', 'O'),
#   ('upcoming', 'VBG', 'O'),
#   ('Ukrainian', 'JJ', 'B-gpe'),
#   ('presidential', 'JJ', 'O'),
#   ('election', 'NN', 'O'),
#   ('will', 'MD', 'O'),
#   ('be', 'VB', 'O'),
#   ('free', 'JJ', 'O'),
#   ('and', 'CC', 'O'),
#   ('fair', 'JJ', 'O'),
#   ('.', '.', 'O')],
#  [('Mr.', 'NNP', 'B-per'),
#   ('Zhvania', 'NNP', 'I-per'),
#   (',', ',', 'O'),
#   ('who', 'WP', 'O'),
#   ('is', 'VBZ', 'O'),
#   ('currently', 'RB', 'O'),
#   ('visiting', 'VBG', 'O'),
#   ('the', 'DT', 'O'),
#   ('United', 'NNP', 'B-geo'),
#   ('States', 'NNPS', 'I-geo'),
#   (',', ',', 'O'),
#   ('made', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('comment', 'NN', 'O'),
#   ('Wednesday', 'NNP', 'B-tim'),
#   ('in', 'IN', 'O'),
#   ('an', 'DT', 'O'),
#   ('interview', 'NN', 'O'),
#   ('with', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Voice', 'NNP', 'B-org'),
#   ('of', 'IN', 'I-org'),
#   ('America', 'NNP', 'I-org'),
#   ('.', '.', 'O')],
#  [('He', 'PRP', 'O'),
#   ('also', 'RB', 'O'),
#   ('expressed', 'VBD', 'O'),
#   ('satisfaction', 'NN', 'O'),
#   ('with', 'IN', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('U.S.', 'NNP', 'B-org'),
#   ('visit', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('which', 'WDT', 'O'),
#   ('began', 'VBD', 'O'),
#   ('Sunday', 'NNP', 'B-tim'),
#   (',', ',', 'O'),
#   ('and', 'CC', 'O'),
#   ('says', 'VBZ', 'O'),
#   ('the', 'DT', 'O'),
#   ('United', 'NNP', 'B-geo'),
#   ('States', 'NNPS', 'I-geo'),
#   ('has', 'VBZ', 'O'),
#   ('a', 'DT', 'O'),
#   ('great', 'JJ', 'O'),
#   ('deal', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('interest', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('Georgia', 'NNP', 'B-org'),
#   ('.', '.', 'O')],
#  [('So', 'RB', 'O'),
#   ('far', 'RB', 'O'),
#   (',', ',', 'O'),
#   ('nearly', 'RB', 'O'),
#   ('100', 'CD', 'O'),
#   ('militants', 'NNS', 'O'),
#   ('have', 'VBP', 'O'),
#   ('been', 'VBN', 'O'),
#   ('reported', 'VBN', 'O'),
#   ('killed', 'VBN', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('region', 'NN', 'O'),
#   ('since', 'IN', 'O'),
#   ('Thursday', 'NNP', 'B-tim'),
#   ('.', '.', 'O')],
#  [('Mr.', 'NNP', 'B-per'),
#   ('Zhvania', 'NNP', 'I-per'),
#   ('has', 'VBZ', 'O'),
#   ('met', 'VBN', 'O'),
#   ('with', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('number', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('high-level', 'JJ', 'O'),
#   ('U.S.', 'NNP', 'B-gpe'),
#   ('officials', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('including', 'VBG', 'O'),
#   ('National', 'NNP', 'B-per'),
#   ('Security', 'NNP', 'I-per'),
#   ('Advisor', 'NNP', 'I-per'),
#   ('Condoleezza', 'NNP', 'I-per'),
#   ('Rice', 'NNP', 'I-per'),
#   ('.', '.', 'O')],
#  [('He', 'PRP', 'O'),
#   ('quoted', 'VBD', 'O'),
#   ('Ms.', 'NNP', 'B-per'),
#   ('Rice', 'NNP', 'I-per'),
#   ('as', 'IN', 'O'),
#   ('saying', 'VBG', 'O'),
#   ('that', 'IN', 'O'),
#   ('Washington', 'NNP', 'B-org'),
#   ('recognizes', 'VBZ', 'O'),
#   ('Georgia', 'NNP', 'B-org'),
#   ("'s", 'POS', 'O'),
#   ('territorial', 'JJ', 'O'),
#   ('integrity', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('regards', 'NNS', 'O'),
#   ('to', 'TO', 'O'),
#   ('Abkhazia', 'NNP', 'B-geo'),
#   (',', ',', 'O'),
#   ('a', 'DT', 'O'),
#   ('pro-Russian', 'JJ', 'O'),
#   ('enclave', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('Georgia', 'NNP', 'B-geo'),
#   ('that', 'WDT', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('run', 'VBN', 'O'),
#   ('its', 'PRP$', 'O'),
#   ('own', 'JJ', 'O'),
#   ('affairs', 'NNS', 'O'),
#   ('since', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('early', 'JJ', 'O'),
#   ('1990s', 'NNS', 'B-tim'),
#   ('.', '.', 'O')],
#  [('Mr.', 'NNP', 'B-per'),
#   ('Zhvania', 'NNP', 'I-per'),
#   ('concludes', 'VBZ', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('visit', 'NN', 'O'),
#   ('Thursday', 'NNP', 'B-tim'),
#   ('.', '.', 'O')],
#  [('South', 'JJ', 'O'),
#   ('Korean', 'JJ', 'B-gpe'),
#   ('police', 'NN', 'O'),
#   ('detained', 'VBD', 'O'),
#   ('a', 'DT', 'O'),
#   ('group', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('anti-Japanese', 'JJ', 'O'),
#   ('protesters', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('Seoul', 'NNP', 'B-geo'),
#   ('Friday', 'NNP', 'B-tim'),
#   ('after', 'IN', 'O'),
#   ('stopping', 'VBG', 'O'),
#   ('their', 'PRP$', 'O'),
#   ('attempt', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('hold', 'VB', 'O'),
#   ('a', 'DT', 'O'),
#   ('mock', 'NN', 'O'),
#   ('funeral', 'NN', 'O'),
#   ('for', 'IN', 'O'),
#   ('Japanese', 'JJ', 'B-gpe'),
#   ('Prime', 'NNP', 'B-per'),
#   ('Minister', 'NNP', 'O'),
#   ('Junichiro', 'NNP', 'B-per'),
#   ('Koizumi', 'NNP', 'I-per'),
#   ('.', '.', 'O')],
#  [('Hundreds', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('riot', 'NN', 'O'),
#   ('police', 'NNS', 'O'),
#   ('surrounded', 'VBN', 'O'),
#   ('about', 'IN', 'O'),
#   ('30', 'CD', 'O'),
#   ('demonstrators', 'NNS', 'O'),
#   ('who', 'WP', 'O'),
#   ('carried', 'VBD', 'O'),
#   ('an', 'DT', 'O'),
#   ('empty', 'JJ', 'O'),
#   ('coffin', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('Mr.', 'NNP', 'B-per'),
#   ('Koizumi', 'NNP', 'I-per'),
#   ("'s", 'POS', 'O'),
#   ('picture', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('a', 'DT', 'O'),
#   ('park', 'NN', 'O'),
#   ('near', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Japanese', 'JJ', 'B-gpe'),
#   ('embassy', 'NN', 'O'),
#   ('for', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('funeral', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Earlier', 'RB', 'O'),
#   (',', ',', 'O'),
#   ('the', 'DT', 'O'),
#   ('same', 'JJ', 'O'),
#   ('group', 'NN', 'O'),
#   ('burned', 'VBD', 'O'),
#   ('a', 'DT', 'O'),
#   ('coffin', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('an', 'DT', 'O'),
#   ('effigy', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('Japanese', 'JJ', 'B-gpe'),
#   ('Ambassador', 'NN', 'O'),
#   ('Toshiyuki', 'NNP', 'B-per'),
#   ('Takano', 'NNP', 'I-per'),
#   ('in', 'IN', 'O'),
#   ('front', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('residence', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('They', 'PRP', 'O'),
#   ('also', 'RB', 'O'),
#   ('fired', 'VBD', 'O'),
#   ('flaming', 'VBG', 'O'),
#   ('arrows', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('which', 'WDT', 'O'),
#   ('failed', 'VBD', 'O'),
#   ('to', 'TO', 'O'),
#   ('reach', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('house', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Anti-Japanese', 'JJ', 'O'),
#   ('sentiment', 'NN', 'O'),
#   ('runs', 'VBZ', 'O'),
#   ('high', 'JJ', 'O'),
#   ('in', 'IN', 'O'),
#   ('South', 'NNP', 'B-geo'),
#   ('Korea', 'NNP', 'I-geo'),
#   ('over', 'IN', 'O'),
#   ('territorial', 'JJ', 'O'),
#   ('claims', 'NNS', 'O'),
#   ('both', 'DT', 'O'),
#   ('countries', 'NNS', 'O'),
#   ('make', 'VBP', 'O'),
#   ('to', 'TO', 'O'),
#   ('a', 'DT', 'O'),
#   ('group', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('small', 'JJ', 'O'),
#   ('islands', 'NNS', 'O'),
#   ('controlled', 'VBN', 'O'),
#   ('by', 'IN', 'O'),
#   ('South', 'NNP', 'B-geo'),
#   ('Korea', 'NNP', 'I-geo'),
#   (',', ',', 'O'),
#   ('and', 'CC', 'O'),
#   ('over', 'IN', 'O'),
#   ('Tokyo', 'NNP', 'B-geo'),
#   ("'s", 'POS', 'O'),
#   ('approval', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('history', 'NN', 'O'),
#   ('books', 'NNS', 'O'),
#   ('that', 'IN', 'O'),
#   ('critics', 'NNS', 'O'),
#   ('say', 'VBP', 'O'),
#   ('downplay', 'NN', 'O'),
#   ('Japan', 'NNP', 'B-org'),
#   ("'s", 'POS', 'O'),
#   ('wartime', 'NN', 'O'),
#   ('atrocities', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('Venezuela', 'NNP', 'B-gpe'),
#   ("'s", 'POS', 'O'),
#   ('defense', 'NN', 'O'),
#   ('minister', 'NN', 'O'),
#   ('says', 'VBZ', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('country', 'NN', 'O'),
#   ('is', 'VBZ', 'O'),
#   ('considering', 'VBG', 'O'),
#   ('building', 'VBG', 'O'),
#   ('unmanned', 'JJ', 'O'),
#   ('planes', 'NNS', 'O'),
#   ('and', 'CC', 'O'),
#   ('may', 'MD', 'O'),
#   ('look', 'VB', 'O'),
#   ('to', 'TO', 'O'),
#   ('allied', 'JJ', 'O'),
#   ('countries', 'NNS', 'O'),
#   ('-', ':', 'O'),
#   ('such', 'JJ', 'O'),
#   ('as', 'IN', 'O'),
#   ('Iran', 'NNP', 'B-geo'),
#   ('-', ':', 'O'),
#   ('for', 'IN', 'O'),
#   ('help', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Defense', 'NN', 'O'),
#   ('Minister', 'NN', 'O'),
#   ('General', 'NNP', 'O'),
#   ('Raul', 'NNP', 'B-per'),
#   ('Baduel', 'NNP', 'I-per'),
#   ('said', 'VBD', 'O'),
#   ('Monday', 'NNP', 'B-tim'),
#   ('in', 'IN', 'O'),
#   ('Caracas', 'NNP', 'B-gpe'),
#   ('that', 'IN', 'O'),
#   ('Venezuela', 'NNP', 'B-gpe'),
#   ('has', 'VBZ', 'O'),
#   ('made', 'VBN', 'O'),
#   ('progress', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('development', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('pilotless', 'JJ', 'O'),
#   ('planes', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('On', 'IN', 'O'),
#   ('Friday', 'NNP', 'B-tim'),
#   (',', ',', 'O'),
#   ('five', 'CD', 'O'),
#   ('soldiers', 'NNS', 'O'),
#   ('were', 'VBD', 'O'),
#   ('killed', 'VBN', 'O'),
#   ('when', 'WRB', 'O'),
#   ('dozens', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('militants', 'NNS', 'O'),
#   ('stormed', 'VBD', 'O'),
#   ('a', 'DT', 'O'),
#   ('military', 'JJ', 'O'),
#   ('checkpoint', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('Orakzai', 'NNP', 'B-geo'),
#   ('.', '.', 'O')],
#  [('He', 'PRP', 'O'),
#   ('also', 'RB', 'O'),
#   ('said', 'VBD', 'O'),
#   ('that', 'IN', 'O'),
#   ('Venezuela', 'NNP', 'B-gpe'),
#   ('will', 'MD', 'O'),
#   ('look', 'VB', 'O'),
#   ('to', 'TO', 'O'),
#   ('other', 'JJ', 'O'),
#   ('countries', 'NNS', 'O'),
#   ('for', 'IN', 'O'),
#   ('help', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('maintaining', 'VBG', 'O'),
#   ('its', 'PRP$', 'O'),
#   ('aging', 'NN', 'O'),
#   ('U.S.-made', 'JJ', 'O'),
#   ('F-5', 'NN', 'O'),
#   ('fighter', 'NN', 'O'),
#   ('jets', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('Venezuela', 'NNP', 'B-gpe'),
#   ('has', 'VBZ', 'O'),
#   ('had', 'VBN', 'O'),
#   ('trouble', 'NN', 'O'),
#   ('maintaining', 'VBG', 'O'),
#   ('the', 'DT', 'O'),
#   ('planes', 'NNS', 'O'),
#   ('since', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('United', 'NNP', 'B-gpe'),
#   ('States', 'NNPS', 'I-gpe'),
#   ('began', 'VBD', 'O'),
#   ('blocking', 'VBG', 'O'),
#   ('arms', 'NNS', 'O'),
#   ('sales', 'NNS', 'O'),
#   ('to', 'TO', 'O'),
#   ('the', 'DT', 'O'),
#   ('South', 'NNP', 'B-org'),
#   ('American', 'NNP', 'I-org'),
#   ('country', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Iran', 'NNP', 'B-geo'),
#   ("'s", 'POS', 'O'),
#   ('foreign', 'JJ', 'O'),
#   ('minister', 'NN', 'O'),
#   ('says', 'VBZ', 'O'),
#   ('nuclear', 'JJ', 'O'),
#   ('talks', 'NNS', 'O'),
#   ('remain', 'VBP', 'O'),
#   ('stalled', 'VBN', 'O'),
#   ('between', 'IN', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('government', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('European', 'JJ', 'O'),
#   ('negotiators', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('Speaking', 'VBG', 'O'),
#   ('to', 'TO', 'O'),
#   ('reporters', 'NNS', 'O'),
#   ('Wednesday', 'NNP', 'B-tim'),
#   ('in', 'IN', 'O'),
#   ('Tehran', 'NNP', 'B-geo'),
#   (',', ',', 'O'),
#   ('Kamal', 'NNP', 'B-org'),
#   ('Kharrazi', 'NNP', 'I-org'),
#   ('said', 'VBD', 'O'),
#   ('Iran', 'NNP', 'B-org'),
#   ('has', 'VBZ', 'O'),
#   ('always', 'RB', 'O'),
#   ('sought', 'VBN', 'O'),
#   ('a', 'DT', 'O'),
#   ('short-term', 'JJ', 'O'),
#   ('suspension', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('its', 'PRP$', 'O'),
#   ('uranium', 'NN', 'O'),
#   ('enrichment', 'NN', 'O'),
#   ('activities', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('but', 'CC', 'O'),
#   ('Britain', 'NNP', 'B-gpe'),
#   (',', ',', 'O'),
#   ('France', 'NNP', 'B-gpe'),
#   ('and', 'CC', 'O'),
#   ('Germany', 'NNP', 'B-gpe'),
#   ('are', 'VBP', 'O'),
#   ('pressing', 'VBG', 'O'),
#   ('for', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('permanent', 'JJ', 'O'),
#   ('one', 'CD', 'O'),
#   ('.', '.', 'O')],
#  [('Iran', 'NNP', 'B-gpe'),
#   ('has', 'VBZ', 'O'),
#   ('suspended', 'VBN', 'O'),
#   ('its', 'PRP$', 'O'),
#   ('enrichment', 'NN', 'O'),
#   ('activities', 'NNS', 'O'),
#   ('as', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('good', 'JJ', 'O'),
#   ('faith', 'NN', 'O'),
#   ('gesture', 'NN', 'O'),
#   ('during', 'IN', 'O'),
#   ('negotiations', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('but', 'CC', 'O'),
#   ('said', 'VBD', 'O'),
#   ('it', 'PRP', 'O'),
#   ('will', 'MD', 'O'),
#   ('decide', 'VB', 'O'),
#   ('in', 'IN', 'O'),
#   ('three', 'CD', 'B-tim'),
#   ('months', 'NNS', 'O'),
#   ('whether', 'IN', 'O'),
#   ('to', 'TO', 'O'),
#   ('continue', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('suspension', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Highly', 'RB', 'O'),
#   ('enriched', 'VBN', 'O'),
#   ('uranium', 'NN', 'O'),
#   ('can', 'MD', 'O'),
#   ('be', 'VB', 'O'),
#   ('used', 'VBN', 'O'),
#   ('to', 'TO', 'O'),
#   ('make', 'VB', 'O'),
#   ('fuel', 'NN', 'O'),
#   ('for', 'IN', 'O'),
#   ('nuclear', 'JJ', 'O'),
#   ('weapons', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('head', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('Iran', 'NNP', 'B-org'),
#   ("'s", 'POS', 'O'),
#   ('Atomic', 'NNP', 'B-org'),
#   ('Energy', 'NNP', 'I-org'),
#   ('Organization', 'NNP', 'I-org'),
#   (',', ',', 'O'),
#   ('Gholamreza', 'NNP', 'B-per'),
#   ('Aghazadeh', 'NNP', 'I-per'),
#   (',', ',', 'O'),
#   ('called', 'VBD', 'O'),
#   ('on', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Europeans', 'NNS', 'B-gpe'),
#   ('to', 'TO', 'O'),
#   ('speed', 'VB', 'O'),
#   ('up', 'RP', 'O'),
#   ('the', 'DT', 'O'),
#   ('talks', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('In', 'IN', 'O'),
#   ('remarks', 'NNS', 'O'),
#   ('today', 'NN', 'B-tim'),
#   (',', ',', 'O'),
#   ('he', 'PRP', 'O'),
#   ('expressed', 'VBD', 'O'),
#   ('hope', 'NN', 'O'),
#   ('the', 'DT', 'O'),
#   ('negotiations', 'NNS', 'O'),
#   ('would', 'MD', 'O'),
#   ('protect', 'VB', 'O'),
#   ('Iran', 'NNP', 'B-org'),
#   ("'s", 'POS', 'O'),
#   ('scientific', 'JJ', 'O'),
#   ('achievements', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('which', 'WDT', 'O'),
#   ('he', 'PRP', 'O'),
#   ('says', 'VBZ', 'O'),
#   ('the', 'DT', 'O'),
#   ('Islamic', 'NNP', 'B-geo'),
#   ('Republic', 'NNP', 'I-geo'),
#   ('will', 'MD', 'O'),
#   ('never', 'RB', 'O'),
#   ('give', 'VB', 'O'),
#   ('up', 'RP', 'O'),
#   ('.', '.', 'O')],
#  [('President', 'NNP', 'B-per'),
#   ('Bush', 'NNP', 'I-per'),
#   ('has', 'VBZ', 'O'),
#   ('declared', 'VBN', 'O'),
#   ('a', 'DT', 'O'),
#   ('state', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('emergency', 'NN', 'O'),
#   ('for', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Gulf', 'NNP', 'B-geo'),
#   ('Coast', 'NNP', 'I-geo'),
#   ('state', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('Louisiana', 'NNP', 'B-geo'),
#   (',', ',', 'O'),
#   ('as', 'IN', 'O'),
#   ('it', 'PRP', 'O'),
#   ('braces', 'VBZ', 'O'),
#   ('for', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('expected', 'VBN', 'O'),
#   ('onslaught', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('Hurricane', 'NNP', 'B-nat'),
#   ('Katrina', 'NNP', 'I-nat'),
#   (',', ',', 'O'),
#   ('set', 'VBN', 'O'),
#   ('to', 'TO', 'O'),
#   ('make', 'VB', 'O'),
#   ('landfall', 'NN', 'O'),
#   ('on', 'IN', 'O'),
#   ('Monday', 'NNP', 'B-tim'),
#   ('.', '.', 'O')],
#  [('Saturday', 'NNP', 'B-tim'),
#   ("'s", 'POS', 'O'),
#   ('emergency', 'NN', 'O'),
#   ('declaration', 'NN', 'O'),
#   ('authorizes', 'VBZ', 'O'),
#   ('federal', 'JJ', 'O'),
#   ('officials', 'NNS', 'O'),
#   ('to', 'TO', 'O'),
#   ('coordinate', 'VB', 'O'),
#   ('all', 'DT', 'O'),
#   ('disaster', 'NN', 'O'),
#   ('relief', 'NN', 'O'),
#   ('efforts', 'NNS', 'O'),
#   ('and', 'CC', 'O'),
#   ('provide', 'VB', 'O'),
#   ('appropriate', 'JJ', 'O'),
#   ('assistance', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('several', 'JJ', 'O'),
#   ('Louisiana', 'NNP', 'B-geo'),
#   ('parishes', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('At', 'IN', 'O'),
#   ('least', 'JJS', 'O'),
#   ('32', 'CD', 'O'),
#   ('suspected', 'JJ', 'O'),
#   ('militants', 'NNS', 'O'),
#   ('were', 'VBD', 'O'),
#   ('killed', 'VBN', 'O'),
#   ('when', 'WRB', 'O'),
#   ('troops', 'NNS', 'O'),
#   ('launched', 'VBD', 'O'),
#   ('a', 'DT', 'O'),
#   ('counter-attack', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Hours', 'NNS', 'O'),
#   ('earlier', 'RB', 'O'),
#   (',', ',', 'O'),
#   ('Louisiana', 'NNP', 'B-geo'),
#   ('and', 'CC', 'O'),
#   ('neighboring', 'JJ', 'O'),
#   ('Mississippi', 'NNP', 'B-org'),
#   ('declared', 'VBD', 'O'),
#   ('their', 'PRP$', 'O'),
#   ('own', 'JJ', 'O'),
#   ('states', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('emergency', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('preparation', 'NN', 'O'),
#   ('for', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('storm', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('and', 'CC', 'O'),
#   ('evacuations', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('low-lying', 'JJ', 'O'),
#   ('areas', 'NNS', 'O'),
#   ('began', 'VBD', 'O'),
#   ('.', '.', 'O')],
#  [('Oil', 'NN', 'O'),
#   ('rigs', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Gulf', 'NNP', 'B-geo'),
#   ('of', 'IN', 'I-geo'),
#   ('Mexico', 'NNP', 'I-geo'),
#   ('were', 'VBD', 'O'),
#   ('evacuated', 'VBN', 'O'),
#   ('as', 'RB', 'O'),
#   ('well', 'RB', 'O'),
#   (',', ',', 'O'),
#   ('as', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('11th', 'JJ', 'B-tim'),
#   ('named', 'VBN', 'O'),
#   ('storm', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('this', 'DT', 'O'),
#   ('year', 'NN', 'O'),
#   ("'s", 'POS', 'O'),
#   ('Atlantic', 'NNP', 'B-geo'),
#   ('hurricane', 'NN', 'O'),
#   ('season', 'NN', 'O'),
#   ('churned', 'VBD', 'O'),
#   ('over', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Gulf', 'NNP', 'B-geo'),
#   ("'s", 'POS', 'O'),
#   ('warm', 'JJ', 'O'),
#   ('waters', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('At', 'IN', 'O'),
#   ('last', 'JJ', 'O'),
#   ('report', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('Katrina', 'NNP', 'B-nat'),
#   ('had', 'VBD', 'O'),
#   ('185', 'CD', 'O'),
#   ('kilometer-per-hour', 'JJ', 'O'),
#   ('winds', 'NNS', 'O'),
#   ('as', 'IN', 'O'),
#   ('it', 'PRP', 'O'),
#   ('moved', 'VBD', 'O'),
#   ('slowly', 'RB', 'O'),
#   ('toward', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('west-northwest', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Hurricane', 'NNP', 'B-nat'),
#   ('Katrina', 'NNP', 'I-nat'),
#   ('slammed', 'VBD', 'O'),
#   ('into', 'IN', 'O'),
#   ('southeast', 'NN', 'O'),
#   ('Florida', 'NNP', 'B-geo'),
#   ('Thursday', 'NNP', 'B-tim'),
#   (',', ',', 'O'),
#   ('leaving', 'VBG', 'O'),
#   ('at', 'IN', 'O'),
#   ('least', 'JJS', 'O'),
#   ('seven', 'CD', 'O'),
#   ('people', 'NNS', 'O'),
#   ('dead', 'JJ', 'O'),
#   ('.', '.', 'O')],
#  [('Israel', 'NNP', 'B-geo'),
#   ("'s", 'POS', 'O'),
#   ('security', 'NN', 'O'),
#   ('cabinet', 'NN', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('approved', 'VBN', 'O'),
#   ('a', 'DT', 'O'),
#   ('plan', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('release', 'VB', 'O'),
#   ('900', 'CD', 'O'),
#   ('Palestinian', 'JJ', 'B-gpe'),
#   ('prisoners', 'NNS', 'O'),
#   ('and', 'CC', 'O'),
#   ('withdraw', 'VB', 'O'),
#   ('troops', 'NNS', 'O'),
#   ('from', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Palestinian', 'JJ', 'B-gpe'),
#   ('town', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('Jericho', 'NNP', 'B-geo'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('plan', 'NN', 'O'),
#   ('calls', 'VBZ', 'O'),
#   ('for', 'IN', 'O'),
#   ('Israel', 'NNP', 'B-geo'),
#   ('to', 'TO', 'O'),
#   ('free', 'VB', 'O'),
#   ('500', 'CD', 'O'),
#   ('Palestinians', 'NNS', 'B-gpe'),
#   ('after', 'IN', 'O'),
#   ('next', 'JJ', 'O'),
#   ('week', 'NN', 'O'),
#   ("'s", 'POS', 'O'),
#   ('Israeli-Palestinian', 'JJ', 'O'),
#   ('summit', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('and', 'CC', 'O'),
#   ('400', 'CD', 'O'),
#   ('others', 'NNS', 'O'),
#   ('over', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('next', 'JJ', 'O'),
#   ('three', 'CD', 'B-tim'),
#   ('months', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('About', 'IN', 'O'),
#   ('8,000', 'CD', 'O'),
#   ('Palestinians', 'NNS', 'B-gpe'),
#   ('are', 'VBP', 'O'),
#   ('in', 'IN', 'O'),
#   ('Israeli', 'JJ', 'B-gpe'),
#   ('custody', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Both', 'DT', 'O'),
#   ('sides', 'NNS', 'O'),
#   ('say', 'VBP', 'O'),
#   ('they', 'PRP', 'O'),
#   ('hope', 'VBP', 'O'),
#   ('to', 'TO', 'O'),
#   ('reach', 'VB', 'O'),
#   ('agreement', 'NN', 'O'),
#   ('at', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Cairo', 'NNP', 'B-geo'),
#   ('summit', 'NN', 'O'),
#   ('on', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('formal', 'JJ', 'O'),
#   ('truce', 'NN', 'O'),
#   ('ending', 'VBG', 'O'),
#   ('more', 'JJR', 'O'),
#   ('than', 'IN', 'O'),
#   ('four', 'CD', 'O'),
#   ('years', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('violence', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Meanwhile', 'RB', 'O'),
#   (',', ',', 'O'),
#   ('Palestinian', 'JJ', 'B-gpe'),
#   ('gunmen', 'NNS', 'O'),
#   ('interrupted', 'VBN', 'O'),
#   ('a', 'DT', 'O'),
#   ('two-week', 'JJ', 'O'),
#   ('old', 'JJ', 'O'),
#   ('de~facto', 'JJ', 'O'),
#   ('truce', 'NN', 'O'),
#   ('Thursday', 'NNP', 'B-tim'),
#   ('with', 'IN', 'O'),
#   ('an', 'DT', 'O'),
#   ('attack', 'NN', 'O'),
#   ('on', 'IN', 'O'),
#   ('an', 'DT', 'O'),
#   ('Israeli', 'JJ', 'B-gpe'),
#   ('military', 'JJ', 'O'),
#   ('vehicle', 'NN', 'O'),
#   ('that', 'WDT', 'O'),
#   ('wounded', 'VBD', 'O'),
#   ('an', 'DT', 'O'),
#   ('Israeli', 'JJ', 'B-gpe'),
#   ('soldier', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('occupied', 'JJ', 'O'),
#   ('Gaza', 'NNP', 'B-geo'),
#   ('Strip', 'NNP', 'I-geo'),
#   ('.', '.', 'O')],
#  [('Witnesses', 'NNS', 'O'),
#   ('said', 'VBD', 'O'),
#   ('Israeli', 'JJ', 'B-gpe'),
#   ('soldiers', 'NNS', 'O'),
#   ('returned', 'VBD', 'O'),
#   ('fire', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('killed', 'VBD', 'O'),
#   ('one', 'CD', 'O'),
#   ('Palestinian', 'JJ', 'B-gpe'),
#   ('gunman', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Elsewhere', 'RB', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('northwest', 'JJS', 'O'),
#   (',', ',', 'O'),
#   ('authorities', 'NNS', 'O'),
#   ('on', 'IN', 'O'),
#   ('Saturday', 'NNP', 'B-tim'),
#   ('found', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('bodies', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('six', 'CD', 'O'),
#   ('people', 'NNS', 'O'),
#   ('who', 'WP', 'O'),
#   ('had', 'VBD', 'O'),
#   ('been', 'VBN', 'O'),
#   ('shot', 'VBN', 'O'),
#   ('dead', 'RB', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Kurram', 'NNP', 'B-geo'),
#   ('region', 'NN', 'O'),
#   ('along', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Afghan', 'JJ', 'B-gpe'),
#   ('border', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('attack', 'NN', 'O'),
#   ('came', 'VBD', 'O'),
#   ('despite', 'IN', 'O'),
#   ('renewed', 'VBN', 'O'),
#   ('efforts', 'NNS', 'O'),
#   ('by', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Palestinian', 'JJ', 'B-gpe'),
#   ('Authority', 'NNP', 'O'),
#   ('to', 'TO', 'O'),
#   ('stop', 'VB', 'O'),
#   ('militants', 'NNS', 'O'),
#   ('from', 'IN', 'O'),
#   ('attacking', 'VBG', 'O'),
#   ('Israeli', 'JJ', 'B-gpe'),
#   ('targets', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('It', 'PRP', 'O'),
#   ('was', 'VBD', 'O'),
#   ('not', 'RB', 'O'),
#   ('immediately', 'RB', 'O'),
#   ('clear', 'JJ', 'O'),
#   ('what', 'WP', 'O'),
#   (',', ',', 'O'),
#   ('if', 'IN', 'O'),
#   ('any', 'DT', 'O'),
#   (',', ',', 'O'),
#   ('effect', 'NN', 'O'),
#   ('it', 'PRP', 'O'),
#   ('would', 'MD', 'O'),
#   ('have', 'VB', 'O'),
#   ('on', 'IN', 'O'),
#   ('summit', 'NN', 'O'),
#   ('plans', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('A', 'DT', 'O'),
#   ('Russian', 'JJ', 'B-gpe'),
#   ('spacecraft', 'NN', 'O'),
#   ('carrying', 'VBG', 'O'),
#   ('an', 'DT', 'O'),
#   ('American', 'JJ', 'B-gpe'),
#   ('space', 'NN', 'O'),
#   ('tourist', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('two', 'CD', 'O'),
#   ('cosmonauts', 'NNS', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('docked', 'VBN', 'O'),
#   ('with', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('International', 'NNP', 'B-art'),
#   ('Space', 'NNP', 'I-art'),
#   ('Station', 'NNP', 'I-art'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('Soyuzcapsule', 'NNP', 'B-art'),
#   ('reached', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('space', 'NN', 'O'),
#   ('station', 'NN', 'O'),
#   ('Monday', 'NNP', 'B-tim'),
#   ('--', 'IN', 'O'),
#   ('two', 'CD', 'O'),
#   ('days', 'NNS', 'O'),
#   ('after', 'IN', 'O'),
#   ('lifting', 'VBG', 'O'),
#   ('off', 'RP', 'O'),
#   ('from', 'IN', 'O'),
#   ('Kazakhstan', 'NNP', 'B-geo'),
#   ('.', '.', 'O')],
#  [('It', 'PRP', 'O'),
#   ('carried', 'VBD', 'O'),
#   ('cosmonauts', 'NNS', 'O'),
#   ('Fyodor', 'NNP', 'B-per'),
#   ('Yurchikhin', 'NNP', 'I-per'),
#   ('and', 'CC', 'O'),
#   ('Oleg', 'NNP', 'B-per'),
#   ('Kotov', 'NNP', 'I-per'),
#   ('and', 'CC', 'O'),
#   ('American', 'JJ', 'B-gpe'),
#   ('computer', 'NN', 'O'),
#   ('software', 'NN', 'O'),
#   ('billionaire', 'NN', 'O'),
#   ('Charles', 'NNP', 'B-per'),
#   ('Simonyi', 'NNP', 'I-per'),
#   ('.', '.', 'O')],
#  [('He', 'PRP', 'O'),
#   ('paid', 'VBD', 'O'),
#   ('$', '$', 'O'),
#   ('25', 'CD', 'O'),
#   ('million', 'CD', 'O'),
#   ('for', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('privilege', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('spaceflight', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('visit', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('the', 'DT', 'O'),
#   ('space', 'NN', 'O'),
#   ('station', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Simonyi', 'NNP', 'B-per'),
#   ('brought', 'VBD', 'O'),
#   ('with', 'IN', 'O'),
#   ('him', 'PRP', 'O'),
#   ('a', 'DT', 'O'),
#   ('gourmet', 'NN', 'O'),
#   ('dinner', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('be', 'VB', 'O'),
#   ('eaten', 'VBN', 'O'),
#   ('Thursday', 'NNP', 'B-tim'),
#   (',', ',', 'O'),
#   ('which', 'WDT', 'O'),
#   ('Russia', 'NNP', 'B-org'),
#   ('marks', 'VBZ', 'O'),
#   ('as', 'IN', 'O'),
#   ('Cosmonauts', 'NNP', 'B-tim'),
#   ('Day', 'NNP', 'I-tim'),
#   ('--', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('anniversary', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('Yuri', 'NNP', 'B-per'),
#   ('Gagarin', 'NNP', 'I-per'),
#   ("'s", 'POS', 'O'),
#   ('first', 'JJ', 'O'),
#   ('manned', 'JJ', 'O'),
#   ('space', 'NN', 'O'),
#   ('flight', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('1961', 'CD', 'B-tim'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('current', 'JJ', 'O'),
#   ('space', 'NN', 'O'),
#   ('station', 'NN', 'O'),
#   ('crew', 'NN', 'O'),
#   ('--', ':', 'O'),
#   ('Russian', 'JJ', 'B-gpe'),
#   ('Mikhail', 'NNP', 'B-per'),
#   ('Tyurin', 'NNP', 'I-per'),
#   ('and', 'CC', 'O'),
#   ('American', 'JJ', 'B-gpe'),
#   ('astronauts', 'NNS', 'O'),
#   ('Miguel', 'NNP', 'B-per'),
#   ('Lopez-Alegria', 'NNP', 'I-per'),
#   ('and', 'CC', 'O'),
#   ('Sunita', 'NNP', 'B-per'),
#   ('Williams', 'NNP', 'I-per'),
#   ('--', ':', 'O'),
#   ('return', 'VBP', 'O'),
#   ('to', 'TO', 'O'),
#   ('Earth', 'NNP', 'B-geo'),
#   ('with', 'IN', 'O'),
#   ('Simonyi', 'NNP', 'B-per'),
#   ('on', 'IN', 'O'),
#   ('April', 'NNP', 'B-tim'),
#   ('20', 'CD', 'I-tim'),
#   ('.', '.', 'O')],
#  [('Palestinian', 'JJ', 'B-gpe'),
#   ('President', 'NNP', 'B-per'),
#   ('Mahmoud', 'NNP', 'I-per'),
#   ('Abbas', 'NNP', 'I-per'),
#   ('says', 'VBZ', 'O'),
#   ('he', 'PRP', 'O'),
#   ('wants', 'VBZ', 'O'),
#   ('a', 'DT', 'O'),
#   ('clear', 'JJ', 'O'),
#   ('position', 'NN', 'O'),
#   ('from', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('United', 'NNP', 'B-geo'),
#   ('States', 'NNPS', 'I-geo'),
#   ('regarding', 'VBG', 'O'),
#   ('implementation', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('"', '``', 'O'),
#   ('road', 'NN', 'O'),
#   ('map', 'NN', 'O'),
#   ('"', '``', 'O'),
#   ('plan', 'NN', 'O'),
#   ('for', 'IN', 'O'),
#   ('peace', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Middle', 'NNP', 'B-geo'),
#   ('East', 'NNP', 'I-geo'),
#   ('.', '.', 'O')],
#  [('Mr.', 'NNP', 'B-per'),
#   ('Abbas', 'NNP', 'I-per'),
#   ('made', 'VBD', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('comment', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('reporters', 'NNS', 'O'),
#   ('as', 'IN', 'O'),
#   ('he', 'PRP', 'O'),
#   ('arrived', 'VBD', 'O'),
#   ('in', 'IN', 'O'),
#   ('Washington', 'NNP', 'B-geo'),
#   ('late', 'JJ', 'O'),
#   ('Tuesday', 'NNP', 'B-tim'),
#   ('for', 'IN', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('meeting', 'NN', 'O'),
#   ('Thursday', 'NNP', 'B-tim'),
#   ('with', 'IN', 'O'),
#   ('President', 'NNP', 'B-per'),
#   ('Bush', 'NNP', 'I-per'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('six', 'CD', 'O'),
#   ('were', 'VBD', 'O'),
#   ('kidnapped', 'VBN', 'O'),
#   ('a', 'DT', 'O'),
#   ('few', 'JJ', 'O'),
#   ('days', 'NNS', 'O'),
#   ('ago', 'RB', 'O'),
#   ('.', '.', 'O')],
#  [('A', 'DT', 'O'),
#   ('White', 'NNP', 'B-org'),
#   ('House', 'NNP', 'I-org'),
#   ('spokesman', 'NN', 'O'),
#   ('said', 'VBD', 'O'),
#   ('Wednesday', 'NNP', 'B-tim'),
#   ('that', 'IN', 'O'),
#   ('Mr.', 'NNP', 'B-per'),
#   ('Bush', 'NNP', 'I-per'),
#   ('believes', 'VBZ', 'O'),
#   ('the', 'DT', 'O'),
#   ('road', 'NN', 'O'),
#   ('map', 'NN', 'O'),
#   ('is', 'VBZ', 'O'),
#   ('the', 'DT', 'O'),
#   ('best', 'JJS', 'O'),
#   ('plan', 'NN', 'O'),
#   ('for', 'IN', 'O'),
#   ('achieving', 'VBG', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('vision', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('two', 'CD', 'O'),
#   ('states', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('Israel', 'NNP', 'B-geo'),
#   ('and', 'CC', 'O'),
#   ('Palestine', 'NNP', 'B-org'),
#   (',', ',', 'O'),
#   ('living', 'VBG', 'O'),
#   ('peacefully', 'RB', 'O'),
#   ('side', 'NN', 'O'),
#   ('by', 'IN', 'O'),
#   ('side', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('2003', 'CD', 'B-tim'),
#   ('plan', 'NN', 'O'),
#   ('calls', 'VBZ', 'O'),
#   ('for', 'IN', 'O'),
#   ('Palestinians', 'NNS', 'B-gpe'),
#   ('to', 'TO', 'O'),
#   ('crack', 'VB', 'O'),
#   ('down', 'RP', 'O'),
#   ('on', 'IN', 'O'),
#   ('terror', 'NN', 'O'),
#   ('groups', 'NNS', 'O'),
#   ('and', 'CC', 'O'),
#   ('build', 'VB', 'O'),
#   ('democratic', 'JJ', 'O'),
#   ('institutions', 'NNS', 'O'),
#   ('ahead', 'RB', 'O'),
#   ('of', 'IN', 'O'),
#   ('final', 'JJ', 'O'),
#   ('status', 'NN', 'O'),
#   ('negotiations', 'NNS', 'O'),
#   ('aimed', 'VBN', 'O'),
#   ('at', 'IN', 'O'),
#   ('ending', 'VBG', 'O'),
#   ('the', 'DT', 'O'),
#   ('Israeli-Palestinian', 'JJ', 'O'),
#   ('conflict', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Mr.', 'NNP', 'B-per'),
#   ('Abbas', 'NNP', 'I-per'),
#   ('said', 'VBD', 'O'),
#   ('he', 'PRP', 'O'),
#   ('will', 'MD', 'O'),
#   ('also', 'RB', 'O'),
#   ('ask', 'VB', 'O'),
#   ('for', 'IN', 'O'),
#   ('economic', 'JJ', 'O'),
#   ('aid', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('and', 'CC', 'O'),
#   ('the', 'DT', 'O'),
#   ('two', 'CD', 'O'),
#   ('men', 'NNS', 'O'),
#   ('are', 'VBP', 'O'),
#   ('expected', 'VBN', 'O'),
#   ('to', 'TO', 'O'),
#   ('discuss', 'VB', 'O'),
#   ('Israel', 'NNP', 'B-org'),
#   ("'s", 'POS', 'O'),
#   ('plan', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('withdraw', 'VB', 'O'),
#   ('from', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Gaza', 'NNP', 'B-geo'),
#   ('Strip', 'NNP', 'I-geo'),
#   ('.', '.', 'O')],
#  [('A', 'DT', 'O'),
#   ('published', 'VBN', 'O'),
#   ('report', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('Spain', 'NNP', 'B-geo'),
#   ('says', 'VBZ', 'O'),
#   ('the', 'DT', 'O'),
#   ('armed', 'JJ', 'O'),
#   ('Basque', 'NNP', 'B-org'),
#   ('separatist', 'NN', 'O'),
#   ('group', 'NN', 'O'),
#   ('ETA', 'NNP', 'B-org'),
#   ('has', 'VBZ', 'O'),
#   ('taken', 'VBN', 'O'),
#   ('responsibility', 'NN', 'O'),
#   ('for', 'IN', 'O'),
#   ('five', 'CD', 'O'),
#   ('attacks', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('northern', 'JJ', 'O'),
#   ('part', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('country', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('recent', 'JJ', 'B-tim'),
#   ('months', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('Gara', 'NNP', 'O'),
#   ('newspaper', 'NN', 'O'),
#   ('Tuesday', 'NNP', 'B-tim'),
#   ('published', 'VBD', 'O'),
#   ('an', 'DT', 'O'),
#   ('ETA', 'NNP', 'B-org'),
#   ('statement', 'NN', 'O'),
#   ('saying', 'VBG', 'O'),
#   ('it', 'PRP', 'O'),
#   ('carried', 'VBD', 'O'),
#   ('out', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('five', 'CD', 'O'),
#   ('attacks', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('June', 'NNP', 'B-tim'),
#   ('and', 'CC', 'I-tim'),
#   ('July', 'NNP', 'I-tim'),
#   ('.', '.', 'O')],
#  [('ETA', 'NNP', 'B-org'),
#   ('says', 'VBZ', 'O'),
#   ('one', 'CD', 'O'),
#   ('target', 'NN', 'O'),
#   ('was', 'VBD', 'O'),
#   ('La', 'NNP', 'B-org'),
#   ('Peineta', 'NNP', 'I-org'),
#   ('stadium', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('which', 'WDT', 'O'),
#   ('was', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('centerpiece', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('Spain', 'NNP', 'B-org'),
#   ("'s", 'POS', 'O'),
#   ('failed', 'VBN', 'O'),
#   ('bid', 'NN', 'O'),
#   ('to', 'TO', 'O'),
#   ('host', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('2012', 'CD', 'B-tim'),
#   ('Olympics', 'NNS', 'I-tim'),
#   ('.', '.', 'O')],
#  [('Spanish', 'JJ', 'B-gpe'),
#   ('Prime', 'NNP', 'B-per'),
#   ('Minister', 'NNP', 'I-per'),
#   ('Jose', 'NNP', 'I-per'),
#   ('Luis', 'NNP', 'I-per'),
#   ('Rodriguez', 'NNP', 'I-per'),
#   ('Zapatero', 'NNP', 'I-per'),
#   ('has', 'VBZ', 'O'),
#   ('offered', 'VBN', 'O'),
#   ('to', 'TO', 'O'),
#   ('hold', 'VB', 'O'),
#   ('peace', 'NN', 'O'),
#   ('talks', 'NNS', 'O'),
#   ('with', 'IN', 'O'),
#   ('ETA', 'NNP', 'B-org'),
#   ('if', 'IN', 'O'),
#   ('it', 'PRP', 'O'),
#   ('renounces', 'VBZ', 'O'),
#   ('violence', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('ETA', 'NNP', 'B-org'),
#   ('has', 'VBZ', 'O'),
#   ('been', 'VBN', 'O'),
#   ('blamed', 'VBN', 'O'),
#   ('for', 'IN', 'O'),
#   ('more', 'JJR', 'O'),
#   ('than', 'IN', 'O'),
#   ('800', 'CD', 'O'),
#   ('deaths', 'NNS', 'O'),
#   ('since', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('1960s', 'NNS', 'B-tim'),
#   (',', ',', 'O'),
#   ('when', 'WRB', 'O'),
#   ('it', 'PRP', 'O'),
#   ('began', 'VBD', 'O'),
#   ('its', 'PRP$', 'O'),
#   ('armed', 'JJ', 'O'),
#   ('campaign', 'NN', 'O'),
#   ('for', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('separate', 'JJ', 'O'),
#   ('Basque', 'NN', 'B-geo'),
#   ('homeland', 'NN', 'I-geo'),
#   ('in', 'IN', 'O'),
#   ('northern', 'JJ', 'O'),
#   ('Spain', 'NNP', 'B-geo'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'B-org'),
#   ('Who', 'NNP', 'I-org'),
#   ('cancelled', 'VBD', 'O'),
#   ('a', 'DT', 'O'),
#   ('March', 'NNP', 'B-tim'),
#   ('13', 'CD', 'I-tim'),
#   ('concert', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('Tampa', 'NNP', 'B-geo'),
#   (',', ',', 'O'),
#   ('Florida', 'NNP', 'B-geo'),
#   (',', ',', 'O'),
#   ('after', 'IN', 'O'),
#   ('lead', 'NN', 'O'),
#   ('singer', 'NN', 'O'),
#   ('Roger', 'NNP', 'B-per'),
#   ('Daltrey', 'NNP', 'I-per'),
#   ('fell', 'VBD', 'O'),
#   ('ill', 'RB', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('63-year-old', 'JJ', 'O'),
#   ('Daltrey', 'NNP', 'B-per'),
#   ('walked', 'VBD', 'O'),
#   ('offstage', 'NN', 'O'),
#   ('during', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('first', 'JJ', 'O'),
#   ('song', 'NN', 'O'),
#   (';', ';', 'O'),
#   ('guitarist', 'NN', 'O'),
#   ('Pete', 'NNP', 'B-per'),
#   ('Townshend', 'NNP', 'I-per'),
#   ('later', 'RB', 'O'),
#   ('told', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('crowd', 'NN', 'O'),
#   ('he', 'PRP', 'O'),
#   ('was', 'VBD', 'O'),
#   ('suffering', 'VBG', 'O'),
#   ('from', 'IN', 'O'),
#   ('bronchitis', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('could', 'MD', 'O'),
#   ('barely', 'RB', 'O'),
#   ('speak', 'VB', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('U.S.', 'NNP', 'B-org'),
#   ('military', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('Afghanistan', 'NNP', 'B-geo'),
#   ('says', 'VBZ', 'O'),
#   ('coalition', 'NN', 'O'),
#   ('forces', 'NNS', 'O'),
#   ('killed', 'VBD', 'O'),
#   ('14', 'CD', 'O'),
#   ('Taleban', 'NNP', 'B-org'),
#   ('militants', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('separate', 'JJ', 'O'),
#   ('clashes', 'NNS', 'O'),
#   ('this', 'DT', 'O'),
#   ('week', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('crowd', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('9,000', 'CD', 'O'),
#   ('then', 'RB', 'O'),
#   ('cheered', 'VBD', 'O'),
#   ('when', 'WRB', 'O'),
#   ('Townshend', 'NNP', 'B-per'),
#   ('said', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('show', 'NN', 'O'),
#   ('had', 'VBD', 'O'),
#   ('been', 'VBN', 'O'),
#   ('rescheduled', 'VBN', 'O'),
#   ('for', 'IN', 'O'),
#   ('March', 'NNP', 'B-tim'),
#   ('25', 'CD', 'I-tim'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'B-org'),
#   ('Who', 'NNP', 'I-org'),
#   ('is', 'VBZ', 'O'),
#   ('currently', 'RB', 'O'),
#   ('touring', 'VBG', 'O'),
#   ('in', 'IN', 'O'),
#   ('support', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('Endless', 'JJ', 'B-art'),
#   ('Wire', 'NNP', 'I-art'),
#   (',', ',', 'O'),
#   ('its', 'PRP$', 'O'),
#   ('first', 'JJ', 'O'),
#   ('album', 'NN', 'O'),
#   ('since', 'IN', 'B-tim'),
#   ('1982', 'CD', 'I-tim'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('band', 'NN', 'O'),
#   ('next', 'IN', 'O'),
#   ('performs', 'VBZ', 'O'),
#   ('March', 'NNP', 'B-tim'),
#   ('17', 'CD', 'I-tim'),
#   ('in', 'IN', 'O'),
#   ('Mexico', 'NNP', 'B-geo'),
#   ('City', 'NNP', 'I-geo'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('U.S.', 'NNP', 'B-org'),
#   ('State', 'NNP', 'I-org'),
#   ('Department', 'NNP', 'I-org'),
#   ('says', 'VBZ', 'O'),
#   ('the', 'DT', 'O'),
#   ('already', 'RB', 'O'),
#   ('poor', 'JJ', 'O'),
#   ('human', 'JJ', 'O'),
#   ('rights', 'NNS', 'O'),
#   ('situation', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('Nepal', 'NNP', 'B-gpe'),
#   ('worsened', 'VBD', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('past', 'JJ', 'B-tim'),
#   ('year', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('with', 'IN', 'O'),
#   ('security', 'NN', 'O'),
#   ('forces', 'NNS', 'O'),
#   ('and', 'CC', 'O'),
#   ('insurgents', 'NNS', 'O'),
#   ('alike', 'RB', 'O'),
#   ('committing', 'VBG', 'O'),
#   ('serious', 'JJ', 'O'),
#   ('human', 'JJ', 'O'),
#   ('rights', 'NNS', 'O'),
#   ('abuses', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('However', 'RB', 'O'),
#   (',', ',', 'O'),
#   ('the', 'DT', 'O'),
#   ('report', 'NN', 'O'),
#   ('says', 'VBZ', 'O'),
#   ('the', 'DT', 'O'),
#   ('governments', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('India', 'NNP', 'B-geo'),
#   ('and', 'CC', 'O'),
#   ('Sri', 'NNP', 'B-per'),
#   ('Lanka', 'NNP', 'B-gpe'),
#   ('generally', 'RB', 'O'),
#   ('respected', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('rights', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('citizens', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('although', 'IN', 'O'),
#   ('serious', 'JJ', 'O'),
#   ('problems', 'NNS', 'O'),
#   ('remain', 'VBP', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('State', 'NNP', 'B-org'),
#   ('Department', 'NNP', 'I-org'),
#   ('criticizes', 'VBZ', 'O'),
#   ('Sri', 'NNP', 'B-per'),
#   ('Lanka', 'NNP', 'B-gpe'),
#   ("'s", 'POS', 'O'),
#   ('government', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('the', 'DT', 'O'),
#   ('Tamil', 'NNP', 'B-geo'),
#   ('Tiger', 'NNP', 'I-geo'),
#   ('rebel', 'NN', 'O'),
#   ('group', 'NN', 'O'),
#   ('for', 'IN', 'O'),
#   ('violating', 'VBG', 'O'),
#   ('a', 'DT', 'O'),
#   ('ceasefire', 'JJ', 'O'),
#   ('accord', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('place', 'NN', 'O'),
#   ('since', 'IN', 'B-tim'),
#   ('2002', 'CD', 'I-tim'),
#   ('.', '.', 'O')],
#  [('It', 'PRP', 'O'),
#   ('also', 'RB', 'O'),
#   ('says', 'VBZ', 'O'),
#   ('Indian', 'JJ', 'B-gpe'),
#   ('officials', 'NNS', 'O'),
# ...
#   ('arrived', 'VBD', 'O'),
#   ('to', 'TO', 'O'),
#   ('restore', 'VB', 'O'),
#   ('peace', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('disarm', 'NN', 'O'),
#   ('ethnic', 'JJ', 'O'),
#   ('militias', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('Regional', 'NNP', 'B-org'),
#   ('Assistance', 'NNP', 'I-org'),
#   ('Mission', 'NNP', 'I-org'),
#   ('to', 'TO', 'O'),
#   ('the', 'DT', 'O'),
#   ('Solomon', 'NNP', 'B-geo'),
#   ('Islands', 'NNP', 'I-geo'),
#   ('(', 'LRB', 'O'),
#   ('RAMSI', 'NNP', 'B-geo'),
#   (')', 'RRB', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('generally', 'RB', 'O'),
#   ('been', 'VBN', 'O'),
#   ('effective', 'JJ', 'O'),
#   ('in', 'IN', 'O'),
#   ('restoring', 'VBG', 'O'),
#   ('law', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('order', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('rebuilding', 'NN', 'O'),
#   ('government', 'NN', 'O'),
#   ('institutions', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('THE', 'DT', 'O'),
#   ('OLIVE-TREE', 'NN', 'O'),
#   ('ridiculed', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('Fig-Tree', 'NN', 'O'),
#   ('because', 'IN', 'O'),
#   (',', ',', 'O'),
#   ('while', 'IN', 'O'),
#   ('she', 'PRP', 'O'),
#   ('was', 'VBD', 'O'),
#   ('green', 'JJ', 'O'),
#   ('all', 'PDT', 'O'),
#   ('the', 'DT', 'O'),
#   ('year', 'NN', 'O'),
#   ('round', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('the', 'DT', 'O'),
#   ('Fig-Tree', 'NN', 'O'),
#   ('changed', 'VBD', 'O'),
#   ('its', 'PRP$', 'O'),
#   ('leaves', 'NNS', 'O'),
#   ('with', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('seasons', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('A', 'DT', 'O'),
#   ('shower', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('snow', 'NN', 'O'),
#   ('fell', 'VBD', 'O'),
#   ('upon', 'IN', 'O'),
#   ('them', 'PRP', 'O'),
#   (',', ',', 'O'),
#   ('and', 'CC', 'O'),
#   (',', ',', 'O'),
#   ('finding', 'VBG', 'O'),
#   ('the', 'DT', 'O'),
#   ('Olive', 'NN', 'O'),
#   ('full', 'JJ', 'O'),
#   ('of', 'IN', 'O'),
#   ('foliage', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('it', 'PRP', 'O'),
#   ('settled', 'VBD', 'O'),
#   ('upon', 'IN', 'O'),
#   ('its', 'PRP$', 'O'),
#   ('branches', 'NNS', 'O'),
#   ('and', 'CC', 'O'),
#   ('broke', 'VBD', 'O'),
#   ('them', 'PRP', 'O'),
#   ('down', 'RP', 'O'),
#   ('with', 'IN', 'O'),
#   ('its', 'PRP$', 'O'),
#   ('weight', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('at', 'IN', 'O'),
#   ('once', 'RB', 'O'),
#   ('despoiling', 'VBG', 'O'),
#   ('it', 'PRP', 'O'),
#   ('of', 'IN', 'O'),
#   ('its', 'PRP$', 'O'),
#   ('beauty', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('killing', 'VBG', 'O'),
#   ('the', 'DT', 'O'),
#   ('tree', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('But', 'CC', 'O'),
#   ('finding', 'VBG', 'O'),
#   ('the', 'DT', 'O'),
#   ('Fig-Tree', 'NN', 'O'),
#   ('denuded', 'VBN', 'O'),
#   ('of', 'IN', 'O'),
#   ('leaves', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('the', 'DT', 'O'),
#   ('snow', 'NN', 'O'),
#   ('fell', 'VBD', 'O'),
#   ('through', 'IN', 'O'),
#   ('to', 'TO', 'O'),
#   ('the', 'DT', 'O'),
#   ('ground', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('and', 'CC', 'O'),
#   ('did', 'VBD', 'O'),
#   ('not', 'RB', 'O'),
#   ('injure', 'VB', 'O'),
#   ('it', 'PRP', 'O'),
#   ('at', 'IN', 'O'),
#   ('all', 'DT', 'O'),
#   ('.', '.', 'O')],
#  [('AN', 'DT', 'O'),
#   ('Editor', 'NN', 'O'),
#   ('who', 'WP', 'O'),
#   ('was', 'VBD', 'O'),
#   ('always', 'RB', 'O'),
#   ('vaunting', 'VBG', 'O'),
#   ('the', 'DT', 'O'),
#   ('purity', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('enterprise', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('and', 'CC', 'O'),
#   ('fearlessness', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('paper', 'NN', 'O'),
#   ('was', 'VBD', 'O'),
#   ('pained', 'VBN', 'O'),
#   ('to', 'TO', 'O'),
#   ('observe', 'VB', 'O'),
#   ('that', 'IN', 'O'),
#   ('he', 'PRP', 'O'),
#   ('got', 'VBD', 'O'),
#   ('no', 'DT', 'O'),
#   ('subscribers', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('One', 'CD', 'O'),
#   ('day', 'NN', 'O'),
#   ('it', 'PRP', 'O'),
#   ('occurred', 'VBD', 'O'),
#   ('to', 'TO', 'O'),
#   ('him', 'PRP', 'O'),
#   ('to', 'TO', 'O'),
#   ('stop', 'VB', 'O'),
#   ('saying', 'VBG', 'O'),
#   ('that', 'IN', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('paper', 'NN', 'O'),
#   ('was', 'VBD', 'O'),
#   ('pure', 'JJ', 'O'),
#   ('and', 'CC', 'O'),
#   ('enterprising', 'JJ', 'O'),
#   ('and', 'CC', 'O'),
#   ('fearless', 'JJ', 'O'),
#   (',', ',', 'O'),
#   ('and', 'CC', 'O'),
#   ('make', 'VB', 'O'),
#   ('it', 'PRP', 'O'),
#   ('so', 'RB', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('interview', 'NN', 'O'),
#   ('airs', 'VBZ', 'O'),
#   ('August', 'NNP', 'B-tim'),
#   ('2', 'CD', 'I-tim'),
#   ('and', 'CC', 'O'),
#   ('3', 'CD', 'B-tim'),
#   ('on', 'IN', 'O'),
#   ('Good', 'NNP', 'B-art'),
#   ('Morning', 'NNP', 'I-art'),
#   ('America', 'NNP', 'I-art'),
#   (',', ',', 'O'),
#   ('and', 'CC', 'O'),
#   ('later', 'RB', 'O'),
#   ('August', 'NNP', 'B-tim'),
#   ('3', 'CD', 'I-tim'),
#   ('on', 'IN', 'O'),
#   ('20/20', 'NNP', 'B-art'),
#   ('.', '.', 'O')],
#  [('"', '``', 'O'),
#   ('If', 'IN', 'O'),
#   ('these', 'DT', 'O'),
#   ('are', 'VBP', 'O'),
#   ('not', 'RB', 'O'),
#   ('good', 'JJ', 'O'),
#   ('qualities', 'NNS', 'O'),
#   (',', ',', 'O'),
#   ('"', '``', 'O'),
#   ('he', 'PRP', 'O'),
#   ('reasoned', 'VBD', 'O'),
#   (',', ',', 'O'),
#   ('"', '``', 'O'),
#   ('it', 'PRP', 'O'),
#   ('is', 'VBZ', 'O'),
#   ('folly', 'RB', 'O'),
#   ('to', 'TO', 'O'),
#   ('claim', 'VB', 'O'),
#   ('them', 'PRP', 'O'),
#   ('.', '.', 'O'),
#   ('"', '``', 'O')],
#  [('Under', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('new', 'JJ', 'O'),
#   ('policy', 'NN', 'O'),
#   ('he', 'PRP', 'O'),
#   ('got', 'VBD', 'O'),
#   ('so', 'RB', 'O'),
#   ('many', 'JJ', 'O'),
#   ('subscribers', 'NNS', 'O'),
#   ('that', 'IN', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('rivals', 'NNS', 'O'),
#   ('endeavoured', 'VBD', 'O'),
#   ('to', 'TO', 'O'),
#   ('discover', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('secret', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('prosperity', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('but', 'CC', 'O'),
#   ('he', 'PRP', 'O'),
#   ('kept', 'VBD', 'O'),
#   ('it', 'PRP', 'O'),
#   (',', ',', 'O'),
#   ('and', 'CC', 'O'),
#   ('when', 'WRB', 'O'),
#   ('he', 'PRP', 'O'),
#   ('died', 'VBD', 'O'),
#   ('it', 'PRP', 'O'),
#   ('died', 'VBD', 'O'),
#   ('with', 'IN', 'O'),
#   ('him', 'PRP', 'O'),
#   ('.', '.', 'O')],
#  [('On', 'IN', 'O'),
#   ('July', 'NNP', 'B-tim'),
#   ('8', 'CD', 'I-tim'),
#   (',', ',', 'I-tim'),
#   ('1947', 'CD', 'I-tim'),
#   (',', ',', 'O'),
#   ('witnesses', 'NNS', 'O'),
#   ('claim', 'VBP', 'O'),
#   ('a', 'DT', 'O'),
#   ('spaceship', 'NN', 'O'),
#   ('with', 'IN', 'O'),
#   ('five', 'CD', 'O'),
#   ('aliens', 'NNS', 'O'),
#   ('aboard', 'IN', 'O'),
#   ('crashed', 'VBN', 'O'),
#   ('on', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('sheep-and-cattle', 'JJ', 'O'),
#   ('ranch', 'NN', 'O'),
#   ('outside', 'IN', 'O'),
#   ('Roswell', 'NNP', 'B-geo'),
#   (',', ',', 'O'),
#   ('an', 'DT', 'O'),
#   ('incident', 'NN', 'O'),
#   ('they', 'PRP', 'O'),
#   ('say', 'VBP', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('been', 'VBN', 'O'),
#   ('covered', 'VBN', 'O'),
#   ('up', 'RP', 'O'),
#   ('by', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('military', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('March', 'NNP', 'B-tim'),
#   ('31', 'CD', 'I-tim'),
#   (',', ',', 'I-tim'),
#   ('1948', 'CD', 'I-tim'),
#   (',', ',', 'I-tim'),
#   ('nine', 'CD', 'I-tim'),
#   ('months', 'NNS', 'O'),
#   ('after', 'IN', 'O'),
#   ('that', 'DT', 'B-tim'),
#   ('day', 'NN', 'I-tim'),
#   (',', ',', 'O'),
#   ('Al', 'NNP', 'B-per'),
#   ('Gore', 'NNP', 'I-per'),
#   ('was', 'VBD', 'O'),
#   ('born', 'VBN', 'O'),
#   ('.', '.', 'O')],
#  [('That', 'DT', 'O'),
#   ('clears', 'VBZ', 'O'),
#   ('up', 'RP', 'O'),
#   ('a', 'DT', 'O'),
#   ('lot', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('things', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('Venezuelan', 'JJ', 'B-gpe'),
#   ('President', 'NNP', 'B-per'),
#   ('Hugo', 'NNP', 'I-per'),
#   ('Chavez', 'NNP', 'I-per'),
#   ('has', 'VBZ', 'O'),
#   ('rallied', 'VBN', 'O'),
#   ('hundreds', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('thousands', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('supporters', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('Caracas', 'NNP', 'B-geo'),
#   ('in', 'IN', 'O'),
#   ('advance', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('December', 'NNP', 'B-tim'),
#   ('3', 'CD', 'I-tim'),
#   ('presidential', 'JJ', 'O'),
#   ('vote', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Mr.', 'NNP', 'B-per'),
#   ('Chavez', 'NNP', 'I-per'),
#   ('told', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('crowd', 'NN', 'O'),
#   ('Sunday', 'NNP', 'B-tim'),
#   ('that', 'IN', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('goal', 'NN', 'O'),
#   ('is', 'VBZ', 'O'),
#   ('not', 'RB', 'O'),
#   ('to', 'TO', 'O'),
#   ('merely', 'RB', 'O'),
#   ('win', 'VB', 'O'),
#   (',', ',', 'O'),
#   ('but', 'CC', 'O'),
#   ('to', 'TO', 'O'),
#   ('outdo', 'VB', 'O'),
#   ('previous', 'JJ', 'O'),
#   ('triumphs', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('way', 'NN', 'O'),
#   ('that', 'WDT', 'O'),
#   ('is', 'VBZ', 'O'),
#   ('overwhelming', 'JJ', 'O'),
#   ('and', 'CC', 'O'),
#   ('crushing', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Polls', 'NNS', 'O'),
#   ('show', 'VBP', 'O'),
#   ('Mr.', 'NNP', 'B-per'),
#   ('Chavez', 'NNP', 'I-per'),
#   ('well', 'RB', 'O'),
#   ('ahead', 'RB', 'O'),
#   ('of', 'IN', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('opponent', 'NN', 'O'),
#   ('Manuel', 'NNP', 'B-per'),
#   ('Rosales', 'NNP', 'I-per'),
#   ('.', '.', 'O')],
#  [('Mr.', 'NNP', 'B-per'),
#   ('Chavez', 'NNP', 'I-per'),
#   ('has', 'VBZ', 'O'),
#   ('built', 'VBN', 'O'),
#   ('strong', 'JJ', 'O'),
#   ('support', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('Venezuela', 'NNP', 'B-geo'),
#   ('for', 'IN', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('criticism', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('Bush', 'NNP', 'B-geo'),
#   ('administration', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('for', 'IN', 'O'),
#   ('programs', 'NNS', 'O'),
#   ('he', 'PRP', 'O'),
#   ('says', 'VBZ', 'O'),
#   ('will', 'MD', 'O'),
#   ('improve', 'VB', 'O'),
#   ('the', 'DT', 'O'),
#   ('lives', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('nation', 'NN', 'O'),
#   ("'s", 'POS', 'O'),
#   ('poor', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Mr.', 'NNP', 'B-per'),
#   ('Rosales', 'NNP', 'I-per'),
#   ('is', 'VBZ', 'O'),
#   ('the', 'DT', 'O'),
#   ('governor', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('Zulia', 'NNP', 'B-geo'),
#   ('state', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('U.S.', 'NNP', 'B-gpe'),
#   ('Senator', 'NNP', 'B-per'),
#   ('John', 'NNP', 'I-per'),
#   ('Warner', 'NNP', 'I-per'),
#   ('of', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('southeastern', 'JJ', 'O'),
#   ('state', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('Virginia', 'NNP', 'B-geo'),
#   (',', ',', 'O'),
#   ('a', 'DT', 'O'),
#   ('prominent', 'JJ', 'O'),
#   ('Republican', 'JJ', 'O'),
#   ('figure', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('debate', 'NN', 'O'),
#   ('over', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('war', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('Iraq', 'NNP', 'B-geo'),
#   (',', ',', 'O'),
#   ('says', 'VBZ', 'O'),
#   ('he', 'PRP', 'O'),
#   ('will', 'MD', 'O'),
#   ('retire', 'VB', 'O'),
#   ('after', 'IN', 'O'),
#   ('finishing', 'VBG', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('term', 'NN', 'O'),
#   ('in', 'IN', 'O'),
#   ('2009', 'CD', 'B-tim'),
#   ('.', '.', 'O')],
#  [('He', 'PRP', 'O'),
#   ('has', 'VBZ', 'O'),
#   ('criticized', 'VBN', 'O'),
#   ('Chavez', 'NNP', 'B-per'),
#   ("'", 'POS', 'O'),
#   ('ties', 'NNS', 'O'),
#   ('to', 'TO', 'O'),
#   ('Cuba', 'NNP', 'B-geo'),
#   ("'s", 'POS', 'O'),
#   ('Fidel', 'NNP', 'B-per'),
#   ('Castro', 'NNP', 'I-per'),
#   (',', ',', 'O'),
#   ('saying', 'VBG', 'O'),
#   ('Venezuelans', 'NNS', 'B-gpe'),
#   ('want', 'VBP', 'O'),
#   ('modernity', 'NN', 'O'),
#   (',', ',', 'O'),
#   ('not', 'RB', 'O'),
#   ('the', 'DT', 'O'),
#   ('Cubanization', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('their', 'PRP$', 'O'),
#   ('country', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Mr.', 'NNP', 'B-per'),
#   ('Rosales', 'NNP', 'I-per'),
#   ('held', 'VBD', 'O'),
#   ('a', 'DT', 'O'),
#   ('campaign', 'NN', 'O'),
#   ('rally', 'NN', 'O'),
#   ('Saturday', 'NNP', 'B-tim'),
#   ('that', 'WDT', 'O'),
#   ('also', 'RB', 'O'),
#   ('attracted', 'VBD', 'O'),
#   ('hundreds', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('thousands', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('supporters', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('Officials', 'NNS', 'O'),
#   ('say', 'VBP', 'O'),
#   ('a', 'DT', 'O'),
#   ('journalist', 'NN', 'O'),
#   ('with', 'IN', 'O'),
#   ('state-controlled', 'JJ', 'O'),
#   ('Russian', 'JJ', 'B-gpe'),
#   ('television', 'NN', 'O'),
#   ('was', 'VBD', 'O'),
#   ('found', 'VBN', 'O'),
#   ('dead', 'JJ', 'O'),
#   ('in', 'IN', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('Moscow', 'NNP', 'B-geo'),
#   ('apartment', 'NN', 'O'),
#   ('early', 'RB', 'O'),
#   ('Friday', 'NNP', 'B-tim'),
#   ('.', '.', 'O')],
#  [('Firefighters', 'NNS', 'O'),
#   ('who', 'WP', 'O'),
#   ('came', 'VBD', 'O'),
#   ('to', 'TO', 'O'),
#   ('put', 'VB', 'O'),
#   ('out', 'RP', 'O'),
#   ('a', 'DT', 'O'),
#   ('fire', 'NN', 'O'),
#   ('at', 'IN', 'O'),
#   ('his', 'PRP$', 'O'),
#   ('apartment', 'NN', 'O'),
#   ('found', 'VBD', 'O'),
#   ('the', 'DT', 'O'),
#   ('body', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('32-year-old', 'JJ', 'B-org'),
#   ('Ilyas', 'NNP', 'B-per'),
#   ('Shurpayev', 'NNP', 'I-per'),
#   ('.', '.', 'O')],
#  [('Police', 'NNS', 'O'),
#   ('said', 'VBD', 'O'),
#   ('he', 'PRP', 'O'),
#   ('appeared', 'VBD', 'O'),
#   ('to', 'TO', 'O'),
#   ('have', 'VB', 'O'),
#   ('been', 'VBN', 'O'),
#   ('strangled', 'VBN', 'O'),
#   ('with', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('belt', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('had', 'VBD', 'O'),
#   ('multiple', 'JJ', 'O'),
#   ('stab', 'NN', 'O'),
#   ('wounds', 'NNS', 'O'),
#   ('.', '.', 'O')],
#  [('Shurpayev', 'NNP', 'B-org'),
#   ('moved', 'VBD', 'O'),
#   ('to', 'TO', 'O'),
#   ('Moscow', 'NNP', 'B-geo'),
#   ('from', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('mostly', 'RB', 'O'),
#   ('Muslim', 'JJ', 'O'),
#   ('Dagestan', 'NNP', 'O'),
#   ('province', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('had', 'VBD', 'O'),
#   ('reported', 'VBN', 'O'),
#   ('extensively', 'RB', 'O'),
#   ('from', 'IN', 'O'),
#   ('Russia', 'NNP', 'B-geo'),
#   ("'s", 'POS', 'O'),
#   ('violence-ridden', 'JJ', 'O'),
#   ('North', 'NNP', 'B-org'),
#   ('Caucasus', 'NNP', 'I-org'),
#   ('region', 'NN', 'O'),
#   ('and', 'CC', 'O'),
#   ('neighboring', 'JJ', 'O'),
#   ('areas', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('Georgia', 'NNP', 'B-geo'),
#   ('.', '.', 'O')],
#  [('More', 'JJR', 'O'),
#   ('than', 'IN', 'O'),
#   ('a', 'DT', 'O'),
#   ('dozen', 'CD', 'O'),
#   ('journalists', 'NNS', 'O'),
#   ('have', 'VBP', 'O'),
#   ('been', 'VBN', 'O'),
#   ('slain', 'VBN', 'O'),
#   ('in', 'IN', 'O'),
#   ('contract-style', 'JJ', 'O'),
#   ('killings', 'NNS', 'O'),
#   ('in', 'IN', 'O'),
#   ('Russia', 'NNP', 'B-geo'),
#   ('since', 'IN', 'B-tim'),
#   ('2000', 'CD', 'I-tim'),
#   ('.', '.', 'O')],
#  [('Many', 'JJ', 'O'),
#   ('journalists', 'NNS', 'O'),
#   ('appear', 'VBP', 'O'),
#   ('to', 'TO', 'O'),
#   ('have', 'VB', 'O'),
#   ('been', 'VBN', 'O'),
#   ('targeted', 'VBN', 'O'),
#   ('for', 'IN', 'O'),
#   ('beatings', 'NNS', 'O'),
#   ('and', 'CC', 'O'),
#   ('killings', 'NNS', 'O'),
#   ('because', 'IN', 'O'),
#   ('of', 'IN', 'O'),
#   ('their', 'PRP$', 'O'),
#   ('attempts', 'NNS', 'O'),
#   ('to', 'TO', 'O'),
#   ('report', 'VB', 'O'),
#   ('on', 'IN', 'O'),
#   ('allegations', 'NNS', 'O'),
#   ('of', 'IN', 'O'),
#   ('official', 'JJ', 'O'),
#   ('corruption', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('Iranian', 'JJ', 'B-gpe'),
#   ('state', 'NN', 'O'),
#   ('media', 'NNS', 'O'),
#   ('are', 'VBP', 'O'),
#   ('reporting', 'VBG', 'O'),
#   ('that', 'IN', 'O'),
#   ('Iran', 'NNP', 'B-geo'),
#   ('is', 'VBZ', 'O'),
#   ('operating', 'VBG', 'O'),
#   ('nearly', 'RB', 'O'),
#   ('500', 'CD', 'O'),
#   ('new', 'JJ', 'O'),
#   ('uranium-enriching', 'JJ', 'O'),
#   ('centrifuges', 'NNS', 'O'),
#   ('at', 'IN', 'O'),
#   ('its', 'PRP$', 'O'),
#   ('Natanz', 'NNP', 'B-geo'),
#   ('nuclear', 'JJ', 'O'),
#   ('facility', 'NN', 'O'),
#   ('.', '.', 'O')],
#  [('The', 'DT', 'O'),
#   ('Islamic', 'NNP', 'B-org'),
#   ('Republic', 'NNP', 'I-org'),
#   ('News', 'NNP', 'I-org'),
#   ('Agency', 'NNP', 'I-org'),
#   ('quoted', 'VBD', 'O'),
#   ('Friday', 'NNP', 'B-tim'),
#   ('an', 'DT', 'O'),
#   ('unnamed', 'JJ', 'O'),
#   ('source', 'NN', 'O'),
#   ('familiar', 'JJ', 'O'),
#   ('with', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('program', 'NN', 'O'),
#   ('as', 'IN', 'O'),
#   ('saying', 'VBG', 'O'),
#   ('that', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('centrifuges', 'NNS', 'O'),
#   ('are', 'VBP', 'O'),
#   ('part', 'NN', 'O'),
#   ('of', 'IN', 'O'),
#   ('3,000', 'CD', 'O'),
#   ('installed', 'VBN', 'O'),
#   ('last', 'JJ', 'O'),
#   ('year', 'NN', 'O'),
#   ('at', 'IN', 'O'),
#   ('the', 'DT', 'O'),
#   ('complex', 'NN', 'O'),
#   ('.', '.', 'O')],
#  ...]

# %%
def word2features(sent, i):
    word = sent[i][0]
    postag = sent[i][1]

    features = {
        'bias': 1.0,
        'word.lower()': word.lower(),
        'word[-3:]': word[-3:],
        'word[-2:]': word[-2:],
        'word.isupper()': word.isupper(),
        'word.istitle()': word.istitle(),
        'word.isdigit()': word.isdigit(),
        'postag': postag,
        'postag[:2]': postag[:2],
    }
    if i > 0:
        word1 = sent[i-1][0]
        postag1 = sent[i-1][1]
        features.update({
            '-1:word.lower()': word1.lower(),
            '-1:word.istitle()': word1.istitle(),
            '-1:word.isupper()': word1.isupper(),
            '-1:postag': postag1,
            '-1:postag[:2]': postag1[:2],
        })
    else:
        features['BOS'] = True

    if i < len(sent)-1:
        word1 = sent[i+1][0]
        postag1 = sent[i+1][1]
        features.update({
            '+1:word.lower()': word1.lower(),
            '+1:word.istitle()': word1.istitle(),
            '+1:word.isupper()': word1.isupper(),
            '+1:postag': postag1,
            '+1:postag[:2]': postag1[:2],
        })
    else:
        features['EOS'] = True

    return features


def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [label for token, postag, label in sent]

def sent2tokens(sent):
    return [token for token, postag, label in sent]

# %% [markdown]
# #### 4. 训练和测试

# %%
X = [sent2feaures(s) for s in sentences]
y = [sent2labels(s) for s in sentences]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0)

# %%
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.1,
    c2=0.2,
    max_iterations=100,
    all_possible_transitions=True
)
crf.fit(X_train, y_train)
# Out:
# /Users/libo/opt/anaconda3/envs/HanLP/lib/python3.7/site-packages/sklearn/base.py:213: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# CRF(algorithm='lbfgs', all_possible_transitions=True, c1=0.1, c2=0.2,
#     keep_tempfiles=None, max_iterations=100)

# %%
labels = list(crf.classes_)
labels.remove('O')
new_classes = sorted(
    labels,
    key=lambda name: (name[0], name[1:])
)
new_classes
# Out:
# ['B-art',
#  'B-eve',
#  'B-geo',
#  'B-gpe',
#  'B-nat',
#  'B-org',
#  'B-per',
#  'B-tim',
#  'I-art',
#  'I-eve',
#  'I-geo',
#  'I-gpe',
#  'I-nat',
#  'I-org',
#  'I-per',
#  'I-tim']

# %%
y_pred = crf.predict(X_test)
print(metrics.flat_classification_report(y_test, y_pred, labels = new_classes))
# Out:
#               precision    recall  f1-score   support
#
#        B-art       1.00      0.03      0.07        29
#        B-eve       1.00      0.25      0.40        24
#        B-geo       0.74      0.89      0.81      1043
#        B-gpe       0.91      0.77      0.84       588
#        B-nat       0.67      0.20      0.31        10
#        B-org       0.76      0.62      0.68       649
#        B-per       0.81      0.81      0.81       546
#        B-tim       0.91      0.84      0.87       589
#        I-art       0.00      0.00      0.00         7
#        I-eve       1.00      0.22      0.36        18
#        I-geo       0.68      0.72      0.70       204
#        I-gpe       0.69      0.53      0.60        17
#        I-nat       1.00      0.50      0.67         2
#        I-org       0.79      0.73      0.76       545
#        I-per       0.80      0.91      0.85       574
#        I-tim       0.78      0.68      0.72       185
#
#    micro avg       0.80      0.78      0.79      5030
#    macro avg       0.78      0.54      0.59      5030
# weighted avg       0.80      0.78      0.78      5030
# /Users/libo/opt/anaconda3/envs/HanLP/lib/python3.7/site-packages/sklearn/utils/validation.py:70: FutureWarning: Pass labels=['B-art', 'B-eve', 'B-geo', 'B-gpe', 'B-nat', 'B-org', 'B-per', 'B-tim', 'I-art', 'I-eve', 'I-geo', 'I-gpe', 'I-nat', 'I-org', 'I-per', 'I-tim'] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   FutureWarning)

# %% [markdown]
# #### 5. 通过CRF训练和测试之后，我们得到的结果如上
